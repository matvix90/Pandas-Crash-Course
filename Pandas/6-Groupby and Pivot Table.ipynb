# %%
import pandas as pd

# %%
def sp500():
    url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
    html = pd.read_html(url, header = 0)
    data = html[0]
    return data
df = sp500()
df
# Out:
#     Symbol             Security SEC filings             GICS Sector  \
# 0      MMM           3M Company     reports             Industrials
# 1      ABT  Abbott Laboratories     reports             Health Care
# 2     ABBV          AbbVie Inc.     reports             Health Care
# 3     ABMD              Abiomed     reports             Health Care
# 4      ACN            Accenture     reports  Information Technology
# ..     ...                  ...         ...                     ...
# 500    YUM      Yum! Brands Inc     reports  Consumer Discretionary
# 501   ZBRA   Zebra Technologies     reports  Information Technology
# 502    ZBH        Zimmer Biomet     reports             Health Care
# 503   ZION        Zions Bancorp     reports              Financials
# 504    ZTS               Zoetis     reports             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  \
# 0              Industrial Conglomerates      St. Paul, Minnesota
# ...

# %%
df.sort_values(by = 'GICS Sector')
# Out:
#     Symbol                                Security SEC filings  \
# 471   VIAC                               ViacomCBS     reports
# 146   DISH                            Dish Network     reports
# 481    DIS                 The Walt Disney Company     reports
# 145  DISCK              Discovery, Inc. (Series C)     reports
# 144  DISCA              Discovery, Inc. (Series A)     reports
# ..     ...                                     ...         ...
# 375    PPL                               PPL Corp.     reports
# 53     ATO                            Atmos Energy     reports
# 178    EXC                            Exelon Corp.     reports
# 410    SRE                           Sempra Energy     reports
# 381    PEG  Public Service Enterprise Group (PSEG)     reports
#
#                 GICS Sector       GICS Sub-Industry    Headquarters Location  \
# 471  Communication Services  Movies & Entertainment       New York, New York
# ...

# %%
df.sort_values(by = ['GICS Sector', 'GICS Sub-Industry'], ascending = False)
# Out:
#     Symbol                    Security SEC filings             GICS Sector  \
# 33     AWK        American Water Works     reports               Utilities
# 27     AEE                 Ameren Corp     reports               Utilities
# 95     CNP          CenterPoint Energy     reports               Utilities
# 113    CMS                  CMS Energy     reports               Utilities
# 153    DTE              DTE Energy Co.     reports               Utilities
# ..     ...                         ...         ...                     ...
# 144  DISCA  Discovery, Inc. (Series A)     reports  Communication Services
# 145  DISCK  Discovery, Inc. (Series C)     reports  Communication Services
# 294   LUMN          Lumen Technologies     reports  Communication Services
# 251    IPG           Interpublic Group     reports  Communication Services
# 352    OMC               Omnicom Group     reports  Communication Services
#
# ...

# %%
df.groupby( by = 'GICS Sector').first()
# Out:
#                        Symbol                         Security SEC filings  \
# GICS Sector
# Communication Services   ATVI              Activision Blizzard     reports
# Consumer Discretionary    AAP               Advance Auto Parts     reports
# Consumer Staples           MO                 Altria Group Inc     reports
# Energy                    APA                  APA Corporation     reports
# Financials                AFL                            Aflac     reports
# Health Care               ABT              Abbott Laboratories     reports
# Industrials               MMM                       3M Company     reports
# Information Technology    ACN                        Accenture     reports
# Materials                 APD         Air Products & Chemicals     reports
# Real Estate               ARE  Alexandria Real Estate Equities     reports
# Utilities                 AES                         AES Corp     reports
#
# ...

# %%
df.groupby( by = 'GICS Sector').sum()['CIK'].sort_values(ascending=False)
# Out:
# GICS Sector
# Information Technology    69484032
# Consumer Discretionary    50896131
# Health Care               49492630
# Industrials               47978338
# Financials                41039298
# Communication Services    29007167
# Real Estate               27016858
# Materials                 23433380
# Utilities                 22498116
# Energy                    17186106
# Consumer Staples          12392940
# Name: CIK, dtype: int64

# %%
pd.pivot_table(df, values='CIK', index=['GICS Sector', 'Symbol'])
# Out:
#                                    CIK
# GICS Sector            Symbol
# Communication Services ATVI     718877
#                        CHTR    1091667
#                        CMCSA   1166691
#                        DIS     1744489
#                        DISCA   1437107
# ...                                ...
# Utilities              PPL      922224
#                        SO        92122
#                        SRE     1032208
#                        WEC      783325
#                        XEL       72903
#
# [505 rows x 1 columns]
